# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import klib

import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# Load data. Read csv file and give them columns name because data does not have columns name

# %%
df = pd.read_csv("data\census.csv", names = ["age",	"workclass", "fnlwgt",	"education", "education_num", "marital-status",	"occupation", "relationship", "race","gender", "capital-gain",	"capital-loss", "hours-per-week", "native-country",	"income-per-anum"])

# %% [markdown]
# Data Investigation

# %%
df.head(15)
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# 5       Married-civ-spouse     Exec-managerial            Wife
# 6    Married-spouse-absent       Other-service   Not-in-family
# 7       Married-civ-spouse     Exec-managerial         Husband
# 8            Never-married      Prof-specialty   Not-in-family
# 9       Married-civ-spouse     Exec-managerial         Husband
# 10      Married-civ-spouse     Exec-managerial         Husband
# 11      Married-civ-spouse      Prof-specialty         Husband
# 12           Never-married        Adm-clerical       Own-child
# 13           Never-married               Sales   Not-in-family
# 14      Married-civ-spouse        Craft-repair         Husband
#
#                    race   gender  capital-gain  capital-loss  hours-per-week  \
# 0                 White     Male          2174             0              40
# 1                 White     Male             0             0              13
# 2                 White     Male             0             0              40
# 3                 Black     Male             0             0              40
# 4                 Black   Female             0             0              40
# 5                 White   Female             0             0              40
# 6                 Black   Female             0             0              16
# 7                 White     Male             0             0              45
# 8                 White   Female         14084             0              50
# 9                 White     Male          5178             0              40
# 10                Black     Male             0             0              80
# 11   Asian-Pac-Islander     Male             0             0              40
# 12                White   Female             0             0              30
# 13                Black     Male             0             0              50
# 14   Asian-Pac-Islander     Male             0             0              40
#
#     native-country income-per-anum
# 0    United-States           <=50K
# 1    United-States           <=50K
# 2    United-States           <=50K
# 3    United-States           <=50K
# 4             Cuba           <=50K
# 5    United-States           <=50K
# 6          Jamaica           <=50K
# 7    United-States            >50K
# 8    United-States            >50K
# 9    United-States            >50K
# 10   United-States            >50K
# 11           India            >50K
# 12   United-States           <=50K
# 13   United-States           <=50K
# 14               ?            >50K

# %% [markdown]
# Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1   workclass        32561 non-null  object
#  2   fnlwgt           32561 non-null  int64
#  3   education        32561 non-null  object
#  4   education_num    32561 non-null  int64
#  5   marital-status   32561 non-null  object
#  6   occupation       32561 non-null  object
#  7   relationship     32561 non-null  object
#  8   race             32561 non-null  object
#  9   gender           32561 non-null  object
#  10  capital-gain     32561 non-null  int64
#  11  capital-loss     32561 non-null  int64
#  12  hours-per-week   32561 non-null  int64
#  13  native-country   32561 non-null  object
#  14  income-per-anum  32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Observation:
#    1.The dataset contains 32561 rows and 15 columns
#    2.There are 9 categorical features and 6 numeric features

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# First we check the null value is present or not in this data set.

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# education_num      0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income-per-anum    0
# dtype: int64

# %% [markdown]
# As we see there is no null value present in the data set.

# %% [markdown]
# I am here dropping two columns education and fnlwgt. Education number is given in data so there is no need of education. fnlwgt has very descreat number it is not helpful to calculate income.

# %%
df = df.drop(labels=['fnlwgt', 'education'],axis=1)
df.head()
# Out:
#    age          workclass  education_num       marital-status  \
# 0   39          State-gov             13        Never-married
# 1   50   Self-emp-not-inc             13   Married-civ-spouse
# 2   38            Private              9             Divorced
# 3   53            Private              7   Married-civ-spouse
# 4   28            Private             13   Married-civ-spouse
#
#            occupation    relationship    race   gender  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country income-per-anum
# 0             0              40   United-States           <=50K
# 1             0              13   United-States           <=50K
# 2             0              40   United-States           <=50K
# 3             0              40   United-States           <=50K
# 4             0              40            Cuba           <=50K

# %% [markdown]
# Checking unique values

# %% [markdown]
# Given data set having some unique values that is '?' (check by unique key), so we need to ckeck in data how many columns have this value.

# %%
df[df == ' ?'].count()
# Out:
# age                   0
# workclass          1836
# education_num         0
# marital-status        0
# occupation         1843
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      583
# income-per-anum       0
# dtype: int64

# %% [markdown]
# Obervation: As we see columns 'workclass', 'occupation' and 'native-country' have ' ?', so we have to replace it with nun.

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df['workclass']=df['workclass'].str.replace('?', 'Private')
df['workclass'].value_counts()
# Out:
#  Private             24532
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['occupation'] = df['occupation'].str.replace('?', 'Prof-specialty')
df['occupation'].value_counts()
# Out:
#  Prof-specialty       5983
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df['native-country'] = df['native-country'].str.replace('?', 'United-States')
df['native-country'].value_counts()
# Out:
#  United-States                 29753
#  Mexico                          643
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
pd.read_pickle(r"D:\projects\adult_census_income_prediction\artifacts\preprocessor.pkl")
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'education_num', 'capital_gain',
#                                   'capital_loss', 'hours_per_week']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[[' '
#                                                                               'State-...
#                                                                               'Italy',
#                                                                               ' '
#                                                                               'Dominican-Republic',
#                                                                               ' '
#                                                                               'Vietnam',
#                                                                               ' '
#                                                                               'Guatemala',
#                                                                               ' '
#                                                                               'Japan',
#                                                                               ' '
#                                                                               'Poland',
#                                                                               ' '
#                                                                               'Columbia',
#                                                                               ' '
#                                                                               'Taiwan',
#                                                                               ' '
#                                                                               'Haiti',
#                                                                               ' '
#                                                                               'Iran',
#                                                                               ' '
#                                                                               'Portugal',
#                                                                               ' '
#                                                                               'Nicaragua',
#                                                                               ' '
#                                                                               'Hungary',
#                                                                               ' '
#                                                                               'Honduras',
#                                                                               ' '
#                                                                               'Scotland',
#                                                                               ' '
#                                                                               'Holand-Netherlands',
#                                                                               ' '
#                                                                               'Ecuador', ...]])),
#                                                  ('scaler', StandardScaler())]),
#                                  ['workclass', 'marital_status', 'occupation',
#                                   'relationship', 'race', 'gender',
#                                   'native_country'])])

# %%
df = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (28970, 13) - Remaining NAs: 0
#
#
# Dropped rows: 3591
#      of which 3591 duplicates. (Rows (first 150 shown): [352, 391, 563, 570, 673, 693, 864, 944, 1042, 1050, 1078, 1219, 1463, 1661, 1673, 1758, 1791, 1881, 1923, 2033, 2091, 2194, 2212, 2248, 2254, 2274, 2378, 2397, 2506, 2617, 2709, 2728, 2744, 2766, 2787, 2791, 2794, 2827, 2835, 2854, 3012, 3076, 3095, 3100, 3147, 3161, 3293, 3308, 3337, 3373, 3379, 3391, 3394, 3445, 3509, 3516, 3603, 3604, 3685, 3706, 3711, 3738, 3748, 3764, 3781, 3803, 3805, 3819, 3851, 3852, 3901, 3902, 3929, 3933, 4020, 4025, 4062, 4063, 4072, 4080, 4128, 4129, 4140, 4152, 4162, 4202, 4272, 4276, 4299, 4306, 4318, 4321, 4342, 4393, 4405, 4408, 4413, 4427, 4461, 4476, 4499, 4502, 4511, 4522, 4531, 4544, 4560, 4628, 4636, 4664, 4676, 4688, 4708, 4766, 4792, 4811, 4823, 4832, 4837, 4867, 4873, 4881, 4951, 4958, 4984, 5021, 5056, 5078, 5087, 5091, 5093, 5104, 5110, 5140, 5203, 5218, 5220, 5226, 5248, 5296, 5302, 5310, 5362, 5438, 5460, 5495, 5526, 5550, 5556, 5564])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 2.76 MB (-85.45%)

# %% [markdown]
# Now we clean the data set by using klib liberary

# %% [markdown]
# In this data set 24 duplicate rows was present. Now our data is clean

# %%
df.head()
# Out:
#    age          workclass  education_num       marital_status  \
# 0   39          State-gov             13        Never-married
# 1   50   Self-emp-not-inc             13   Married-civ-spouse
# 2   38            Private              9             Divorced
# 3   53            Private              7   Married-civ-spouse
# 4   28            Private             13   Married-civ-spouse
#
#            occupation    relationship    race   gender  capital_gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital_loss  hours_per_week  native_country income_per_anum
# 0             0              40   United-States           <=50K
# 1             0              13   United-States           <=50K
# 2             0              40   United-States           <=50K
# 3             0              40   United-States           <=50K
# 4             0              40            Cuba           <=50K

# %%
df.shape
# Out:
# (28970, 13)

# %% [markdown]
# There are 32537 rows and 15 columns in this data set

# %%
df.describe()
# Out:
#                 age  education_num  capital_gain  capital_loss  hours_per_week
# count  28970.000000   28970.000000   28970.00000  28970.000000    28970.000000
# mean      39.280428      10.100759    1203.01184     97.597825       40.652054
# std       13.682949       2.647603    7794.72045    424.880797       12.748275
# min       17.000000       1.000000       0.00000      0.000000        1.000000
# 25%       28.000000       9.000000       0.00000      0.000000       40.000000
# 50%       38.000000      10.000000       0.00000      0.000000       40.000000
# 75%       48.000000      13.000000       0.00000      0.000000       45.000000
# max       90.000000      16.000000   99999.00000   4356.000000       99.000000

# %% [markdown]
# In above description the average age is 38.58 and the average of education is 10.08 which is good
# that showing mostly of the people are above high school grade. Average of working hour is showing 40.44.
# In USA working days are five that means people waorks 8 hours in a day.

# %%
categorical=df.select_dtypes(exclude="number").columns
numerical=df.select_dtypes(include='number').columns
print(categorical,'\n',numerical)
# Out:
# Index(['workclass', 'marital_status', 'occupation', 'relationship', 'race',
#        'gender', 'native_country', 'income_per_anum'],
#       dtype='object')
#  Index(['age', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
# plot for categorical columns
plt.figure(figsize=(25, 15))
plt.suptitle('First Chart of bivariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8,y=1)
for i in range(0, len(categorical)):
    plt.subplot(3, 3, i+1)
    sns.histplot(data = df, x = df[categorical[i]], hue = "income_per_anum");
    plt.xlabel(categorical[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# Variable Overview

# %% [markdown]
# Observation:
#
# Categorical Features:
# 1.workclass
# 2.marital_status
# 3.occupation
# 4.relationship
# 5.race
# 6.gender
# 7.native_country
# 8.income_per_anum
#
# Numerical Features:
# 1.age
# 2.education_num
# 3.capital_gain
# 4.capital_loss
# 5.hours_per_week

# %% [markdown]
# Categorical Features

# %% [markdown]
# Workclass

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data = df, x = df["workclass"], hue = 'income_per_anum')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#    1.The workclass of most people is Private (74%)
#    2.In private job most people's income are greater than 50k

# %% [markdown]
# Education

# %% [markdown]
# Observation
#   1. For the people belonging to Bachelors, Masters, Doctorate and Prof-school category,there are more people earning more than 50K

# %% [markdown]
# Marital status

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data = df, x = "marital_status", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#   1. The marital_status of most people earning more than 50K is Married-civ-spouse

# %% [markdown]
# Occupation

# %%
plt.figure(figsize=(25, 10))
sns.histplot(data = df, x = "occupation", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#    1.Adults in Exec-managerial and Pro-specialty roles are equally likely to earn more than 50K dollars an year

# %% [markdown]
# Relationship

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data = df, x = "relationship", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#   1. Husbands are earning more than $50K compare to all.

# %% [markdown]
# Race

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data = df, x = "race", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#   1. Most of the people surveyed are white
#   2. People who earn more than 50k a year are mostly white

# %% [markdown]
# Gender

# %%
print(df['gender'].value_counts())
print("-------------------------------")
print(f"average (mean) of male- {df[df['gender']==' Male']['age'].mean()}")
print(f"average (mean) of female- {df[df['gender']==' Female']['age'].mean()}")
# Out:
#  Male      19151
#  Female     9819
# Name: gender, dtype: int64
# -------------------------------
# average (mean) of male- 40.037491514803406
# average (mean) of female- 37.8038496791934

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data = df, x = "gender", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#   1. The ratio of male to female is about 2:1
#   2. The properation of earning more than 50K is higher in male
#   3. average (mean) of male- 39.43605051664753
#   4.average (mean) of female- 36.864709161865825

# %% [markdown]
# Native country

# %%
plt.figure(figsize=(35, 10))
sns.histplot(data = df, x = "native_country", hue = "income_per_anum")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observation:
#    This data has many countries but most of the people belongs to United- States

# %% [markdown]
# Some other analysis

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x='income_per_anum', y='age', data=df)
# Out:
# <Axes: xlabel='income_per_anum', ylabel='age'>

# %% [markdown]
# Observation- In above analysis average  age of people, who's income is greater than 50K is above than 40 and average age of peoples who's income is less than 50K is less than 40.

# %% [markdown]
# Numerical features

# %% [markdown]
# Density

# %%
# plot for numerical columns
plt.figure(figsize=(25, 15))
plt.suptitle('First Chart of Univariate Analysis of Numeric Features', fontsize=20, fontweight='bold', alpha=0.8,y=1)
#numeric = ['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']
for i in range(0, len(numerical)):
    plt.subplot(2, 3, i+1)
    sns.distplot(x=df[numerical[i]])
    plt.xlabel(numerical[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
# plot for numerical columns
plt.figure(figsize=(15, 6))
plt.suptitle('First Box plot of Numeric Features', fontsize=20, fontweight='bold', alpha=0.8,y=1)
for i in range(0, len(numerical)):
    plt.subplot(2, 3, i+1)
    sns.boxplot(data=df, y=df[numerical[i]], x='income_per_anum', palette=['b', 'g'])
    plt.xlabel(numerical[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# Observation:
#    1. density of people is more who's age is approximately between 20 to 45
#    2. Those people who earn less than $50k have average education is 10th, while who earn more thn $50k have average education approximately 13
#    3. capital gain and capital loss are concentrated on zero
#    4. people who work 40 hours per week earn leass tah $50k, while who earn more than $50k work approximately 50 hours per week
#    4. There are some outliers in every numerical features

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df)
# Out:
# <Axes: >
